# %%
# This is a comment
print("Hello, Python!")
# Out:
# Hello, Python!

# %% [markdown]
# #### Getting user information

# %%
name = "John"
print("Hello, " + name)
# Out:
# Hello, John

# %% [markdown]
# #### Calculations

# %%
print(4+5)
#9
print(9*7)
#63
print(-1/4)
#-0.25
print(1/3)
#0.3333333333333333
print(((2050/5)-32)/9)
#42.0
print(2**10)
#1024
print((9-3)/(2*(1+2)))
# Out:
# 9
# 63
# -0.25
# 0.3333333333333333
# 42.0
# 1024
# 1.0

# %%
# Out:
# 1.0
